# %%
print 'This is a test to see if I can update this notebook. I am not able to open the other notebook.'

# %%
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import StringIO

# %%
#get the information from the Hinode flare catalog
#The important columns here is the start and end time in X-rays, peak X-ray time, event loc (in arcseconds), 
#      X-ray class (defined by GOES)
hinode_url = 'http://st4a.stelab.nagoya-u.ac.jp/hinode_flare/csv/all_event.csv'

s = StringIO.StringIO(requests.get(hinode_url).content)
flare_catalog = pd.read_csv(s)
flare_catalog.head()
#Column descreption : 
#   Event No. - numeric event number - can be used as an ID.
#   GOES start - the GOES aka X-ray start time.
#   end - the GEOS end time.
#   peak - the peak of the event.
#   AR location - TBD - Nicole.
#   X-ray class - TBD - Nicole.
#   event loc.(EW) - East/West coordinate of the event.
#   event loc.(NS) - North/Sounth coordinate of the event.
#The next columns are observers data : 
#   SOT - Instrument Observer.
#   XRT - Instrument Observer.
#   EIS - Instrument Observer.
#   RHESSI - Reuven Ramaty High Energy Solar Spectroscope Imager.
#   NoRH - Nobeyama Radioheliograph.
# Out:
#    # event No.        GOES start               end              peak  \
# 0            0  2006/10/20 19:17  2006/10/20 19:48  2006/10/20 19:20
# 1           10  2006/10/21 15:13  2006/10/21 15:41  2006/10/21 15:25
# 2           20  2006/10/21 16:18  2006/10/21 16:30  2006/10/21 16:21
# 3           30  2006/10/21 18:03  2006/10/21 18:19  2006/10/21 18:10
# 4           40  2006/10/21 18:24  2006/10/21 19:28  2006/10/21 18:58
#
#   AR location X-ray class  event loc. (EW)  event loc. (NS)  SOT XRT  EIS  \
# 0      S05W19        A4.3              320             -177    0   0    0
# 1      S03W27        A6.4              452             -132    0   0    0
# 2      S03W28        A7.1              460             -132    0   0    0
# 3      S02W29        A7.1              478             -122    0   0    0
# 4      S03W32        A7.8              523             -143    0   0    0
#
#   RHESSI NoRH
# 0     no  NaN
# 1     no  NaN
# 2     no  NaN
# 3     no  NaN
# 4     no  NaN
