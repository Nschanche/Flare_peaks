# %% [markdown]
# Investigating solar flares
# ==========================
# Solar flares are sudden, powerful emissions of magnetic energy from the solar atmosphere. They are usually occur around sunspots, which are points on the sun's photosphere where the magnetic field is concentrated, resulting in a lower surface temperature. The area surrounding the sunspot where there is an increased level of magnetic activity is known as an active region.  When the emitted radiation and sometimes associated charged particles from the flare reaches the earth, it can damage satellites, disrupt radio communications and interfere with power line transmissions.
#
# ![Solar flare effects](http://chemtrailsplanet.files.wordpress.com/2013/05/massive-solar-flare-effects.gif)
#
# Solar flares usually occur in three stages. In the first stage (the **precursor** stage), a release of magnetic energy is triggered. Soft X-rays (low-energy X-rays) are detected in this stage. In the second stage (the **impulsive stage**), protons and electrons are accelerated to very high energies. Radio waves, hard X-rays and gamma rays are detected in this stage. In the final stage (the **decay** stage), a slow build up and decay of soft X-rays is detected. The duration of each of these stages ranges from a few seconds to about an hour.
#
# ![Solar flare](http://www.astronomynow.com/news/n1208/15solarflares/sun_400x225.jpg)
#
# The frequency of solar flares is correlated with the Sun's 11-year cycle. When the solar cycle is at a minimum, active regions are small and rare, and few solar flares occur. As the cycle approaches a maximum, the frequency and intensity of solar flares increase.
#
# ![Solar cycle](http://cdn.phys.org/newman/gfx/news/2012/solarflaresi.gif)
#
# Solar flares cannot be seen by the naked eye (Never ever look at the sun!). This needs the use of specialized instruments, typically optical and radio telescopes. Since solar flares are such interesting but poorly understood phenomena, they have been primary objects of investigation for a number of space missions. Examples of these are Yohkoh, WIND, [RHESSI](http://hesperia.gsfc.nasa.gov/rhessi3/), [NoRH](http://solar.nro.nao.ac.jp/norh/), SOHO, [TRACE](http://science.nasa.gov/missions/trace/), [SDO](http://en.wikipedia.org/wiki/Solar_Dynamics_Observatory) and Hinode. One of the more startling findings of these missions is the brief appearance of unicorns in the Sun's corona during the decay stage of some solar flares; These mythical creatures were previously thought to exist only in fairy tales and the active imagination of preschoolers:
#
# ![Unicorn](http://th09.deviantart.net/fs70/PRE/f/2013/115/f/5/solar_flare_by_kittehkatbar-d62yici.png)
#
# But alas I digress...

# %%
# %matplotlib inline 

import re
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
#import requests_cache
import seaborn as sns
import tarfile
from StringIO import StringIO
from datetime import datetime
from datetime import timedelta
from sunpy.net import hek
import threading

# %% [markdown]
# Hinode is a Japanese mission that was started in 2006. It keeps a [catalog](http://link.springer.com/article/10.1007%2Fs11207-012-9983-y) of flares that have been observed by instruments aboard the Hinode satellite. We begin by reading the catalog into a dataframe. Every row in the catalog is a solar flare (referred to as an "event" in the catalog documentation).

# %%
# Get the information from the Hinode flare catalog.
# The important columns here are the start and end time of X-rays, peak X-ray
# time, event loc (in arcseconds) and X-ray class (defined by GOES)
HINODE_URL = 'http://st4a.stelab.nagoya-u.ac.jp/hinode_flare/csv/all_event.csv'

strio = StringIO(requests.get(HINODE_URL).content)
flare_catalog = pd.read_csv(strio)
flare_catalog.head()

# Column descriptions : 
#   Event No. - numeric event number - can be used as an ID.
#   GOES start - X-ray start time, as observed by the GOES instrument.
#   end - the GOES end time.
#   peak - the X-ray peak time of the event, as determined by GOES.
#   AR location - location of the flaring region in heliographic coordinates.
#       *Note that solar coordinates are flipped compared to earth.  The left
#        side of the sun is East and the right side of the sun is the west.
#   X-ray class - class(ie size) of the flare, determined by the X-ray flux
#       observed with GOES
#   event loc.(EW) - East/West location of the event relative to the center
#       of the Sun's disc (measured in arcseconds).
#   event loc.(NS) - North/South location of the flare relative to the center
#       of the Sun's disc (meaured in arcseconds).
#
# The next columns indicate whether other instruments observed the event : 
#   SOT - Number of images taken of the event by the SOT instrument onboard Hinode 
#   XRT - Number of images taken of the event by the XRT instrument onboard Hinode 
#   EIS - Number of images taken of the event by the EIS instrument onboard Hinode 
#   RHESSI - If the flare was also observed by RHESSI, this is the maximum energy
#       range of hard X-rays observed by RHESSI.
#   NoRH - Nobeyama Radioheliograph.

# ****NOTE: We only want data from July 2010 and later, since that is when the
# SDO spacecraft came into operation. The SDO houses the Atmospheric Imaging
# Assembly, whose data we will use in this project.
# Out:
#    # event No.        GOES start               end              peak  \
# 0            0  2006/10/20 19:17  2006/10/20 19:48  2006/10/20 19:20
# 1           10  2006/10/21 15:13  2006/10/21 15:41  2006/10/21 15:25
# 2           20  2006/10/21 16:18  2006/10/21 16:30  2006/10/21 16:21
# 3           30  2006/10/21 18:03  2006/10/21 18:19  2006/10/21 18:10
# 4           40  2006/10/21 18:24  2006/10/21 19:28  2006/10/21 18:58
#
#   AR location X-ray class  event loc. (EW)  event loc. (NS) SOT XRT  EIS  \
# 0      S05W19        A4.3              320             -177   0   0    0
# 1      S03W27        A6.4              452             -132   0   0    0
# 2      S03W28        A7.1              460             -132   0   0    0
# 3      S02W29        A7.1              478             -122   0   0    0
# 4      S03W32        A7.8              523             -143   0   0    0
#
#   RHESSI NoRH
# 0     no  NaN
# 1     no  NaN
# 2     no  NaN
# 3     no  NaN
# 4     no  NaN

# %% [markdown]
# It is possible that the latitude of the event could affect the type of flare.  We would not expect that longitude matters.
# The latidude may matter because of the solar cycle.  As the solar cycle goes from minimum activity to maximum activity, the sunspot location tends to move from higher latitudes down to the equator. So, if the latitude shows a correlation, that may suggest that the type of flare is related to the solar cycle.

# %%
#We will not use the RHESSI or NoRH data at all, so we can just remove those columns.
flare_catalog = flare_catalog.drop(['RHESSI','NoRH'], 1)
flare_catalog.head()

# Add new columns for the heliographic latitude and longitude. 
flare_catalog["latitude"] = flare_catalog['AR location'].apply(
    lambda x: re.match("[NS](\d{2})[EW](\d{2})", x).group(1))
flare_catalog["longitude"] = flare_catalog['AR location'].apply(
    lambda x: re.match("[NS](\d{2})[EW](\d{2})", x).group(2))

# Only look at dates after August of 2013.
# This is a somewhat arbitrary cutoff. We need dates after 2010 because
# that is when AIA launched. We just took the most recent year so that we
# would have fewer samples to go through to ensure we have time to find 
# peak AIA times for them all.
dates = flare_catalog['GOES start']
cutoff = pd.to_datetime('2006/08/01 00:00')
recent_flare_catalog = flare_catalog[pd.to_datetime(dates) >= cutoff]
recent_flare_catalog.reset_index(drop=True, inplace=True)
recent_flare_catalog.head()
# Out:
#    # event No.        GOES start               end              peak  \
# 0            0  2006/10/20 19:17  2006/10/20 19:48  2006/10/20 19:20
# 1           10  2006/10/21 15:13  2006/10/21 15:41  2006/10/21 15:25
# 2           20  2006/10/21 16:18  2006/10/21 16:30  2006/10/21 16:21
# 3           30  2006/10/21 18:03  2006/10/21 18:19  2006/10/21 18:10
# 4           40  2006/10/21 18:24  2006/10/21 19:28  2006/10/21 18:58
#
#   AR location X-ray class  event loc. (EW)  event loc. (NS) SOT XRT  EIS  \
# 0      S05W19        A4.3              320             -177   0   0    0
# 1      S03W27        A6.4              452             -132   0   0    0
# 2      S03W28        A7.1              460             -132   0   0    0
# 3      S02W29        A7.1              478             -122   0   0    0
# 4      S03W32        A7.8              523             -143   0   0    0
#
#   latitude longitude
# 0       05        19
# 1       03        27
# 2       03        28
# 3       02        29
# 4       03        32

# %% [markdown]
# Sunspots are classified by the complexity of their magnetic configuration. In general, the more complex the region, the more likely it is to flare. The sunspot information can be found on the Space Weather Prediction Center (SWPC)'s [website](http://www.swpc.noaa.gov/ftpmenu/warehouse.html). The SWPC keeps its own list of events, as well as the data about sunspots. We first read in the list of events for the year 2013, then extract the sunspot data.

# %%
# SWPC's events for a given day are stored in a separate file, and all the files
# for the year 2013 are in a compressed archive. Each of the files looks like 
# the one below.

test_str = """
:Product: 20121229events.txt
:Created: 2013 Jan 01 0332 UT
:Date: 2012 12 29
# Prepared by the U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center
# Please send comments and suggestions to SWPC.Webmaster@noaa.gov 
#
# Missing data: ////
# Updated every 30 minutes.
#                            Edited Events for 2012 Dec 29
#
#Event    Begin    Max       End  Obs  Q  Type  Loc/Frq   Particulars       Reg#
#-------------------------------------------------------------------------------

 180       0557   0557      0557  LEA  G   RBR  410       200                   

 190       1203   1209      1214  G15  5   XRA  1-8A      B6.3    3.0E-04   1638

 200       1927   1933      1939  G15  5   XRA  1-8A      C1.5    7.3E-04   1638
 200       1929   1931      1940  HOL  3   FLA  N12E51    SF      ERU       1638
"""

# Note that the separators in the above file are spaces, not tabs. We will
# therefore need to develop functionality that converts files like these into
# a format that can be recognized by pandas.

def split_and_purge(in_str, delim=None, purge=["", "+"]):
    """Splits a string into an array of strings, removing unwanted strings."""
    pieces = []
    if delim is None:
        pieces = in_str.split()  # Split for both spaces and tabs.
    else:
        pieces = in_str.split(delim)
    return [piece for piece in pieces if piece not in purge]

def parse_events(events_file):
    """Parses an swpc events file into a pandas-friendly form."""
    # Split into lines.
    lines = split_and_purge(events_file, delim="\n")
    
    # Throw away the first 10 lines. We do not need the info contained therein.
    lines = lines[10:]

    if len(lines) < 2:
        return ""

    # Get the column titles. Clean them.
    title_row = split_and_purge(lines[0])
    title_row = [title.replace("#", "") for title in title_row]
    
    # We merge the Particulars and Reg columns since these are sometimes left
    # blank. The other fields do not seem to have blank values (based on
    # spot-checking).
    title_row = title_row[:-1]
    
    # Get the rows.
    rows = []
    for line in lines[2:]:
        items = split_and_purge(line)
        
        # Too few items.
        if len(items) < 8:
            continue
        
        # Take the first 8 columns as distinct items. Remaining items are
        # thrown together into a single column.
        rows.append(items[:8] + [" ".join(items[8:])])

    # Create csv.
    strio = StringIO()
    writer = csv.writer(strio)
    writer.writerows([title_row] + rows)
    return strio.getvalue()
    
# Test the function above.
pd.read_csv(StringIO(parse_events(test_str)))
# Out:
#    Event  Begin   Max   End  Obs  Q Type Loc/Frq        Particulars
# 0    180    557   557   557  LEA  G  RBR     410                200
# 1    190   1203  1209  1214  G15  5  XRA    1-8A  B6.3 3.0E-04 1638
# 2    200   1927  1933  1939  G15  5  XRA    1-8A  C1.5 7.3E-04 1638
# 3    200   1929  1931  1940  HOL  3  FLA  N12E51        SF ERU 1638

# %%
# We proceed to read in all SWPC events for the year 2013 into a dataframe.

SWPC_2013_URL = "http://www.swpc.noaa.gov/ftpdir/warehouse/2013/2013_events.tar.gz"
strio = StringIO(requests.get(SWPC_2013_URL).content)
tarred = tarfile.open("r:gz", fileobj=strio)

swpc_by_day = []
for tarinfo in tarred:
    if not tarinfo.isdir():
        extracted = tarred.extractfile(tarinfo).read()
        day = re.match(r"^2013_events/(\d+)events.txt", tarinfo.name).group(1)
        df = pd.read_csv(StringIO(parse_events(extracted)))
        df["Date"] = [day] * len(df)
        swpc_by_day.append(df)

# Form a single dataframe. Replace '////'
swpc = pd.concat(swpc_by_day)
for col in list(swpc.columns):
    swpc[col] = swpc[col].apply(lambda x: np.nan if "////" in str(x) else x)

swpc.sort(["Date", "Begin"], ascending=[1, 1], inplace=True)
swpc.reset_index(drop=True, inplace=True)
swpc.head()
# Out:
#    Event Begin   Max   End  Obs  Q Type  Loc/Frq        Particulars      Date
# 0    180   557   557   557  LEA  G  RBR      410                200  20121229
# 1    190  1203  1209  1214  G15  5  XRA     1-8A  B6.3 3.0E-04 1638  20121229
# 2    200  1927  1933  1939  G15  5  XRA     1-8A  C1.5 7.3E-04 1638  20121229
# 3    200  1929  1931  1940  HOL  3  FLA   N12E51        SF ERU 1638  20121229
# 4    210   142   NaN   143  PAL  C  RSP  025-052              III/1  20121230

# %%
# Next, we read SWPC Sunspot Data, similarly to above.

sunspot_test = """
:Product: 0105SRS.txt
:Issued: 2013 Jan 05 0030 UTC
# Prepared jointly by the U.S. Dept. of Commerce, NOAA,
# Space Weather Prediction Center and the U.S. Air Force.
#
Joint USAF/NOAA Solar Region Summary
SRS Number 5 Issued at 0030Z on 05 Jan 2013
Report compiled from data received at SWO on 04 Jan
I.  Regions with Sunspots.  Locations Valid at 04/2400Z 
Nmbr Location  Lo  Area  Z   LL   NN Mag Type
1638 N13W34   308  0080 Hsx  02   01 Alpha
1640 N28W48   322  0320 Eki  13   24 Beta-Gamma-Delta
1641 N04W05   279  0040 Cao  08   02 Beta
1642 S24E22   252  0100 Hsx  02   01 Alpha
1644 N15E35   239  0040 Hsx  02   01 Alpha
1645 S13W18   292  0050 Dao  05   08 Beta
1646 N14E45   229  0030 Hax  01   01 Alpha
1647 N16W55   329  0030 Cao  05   04 Beta
1648 N05E53   221  0020 Cro  03   02 Beta
1649 S14E74   200  0060 Hsx  02   01 Alpha
1650 S26E77   197  0050 Hsx  02   01 Alpha
1651 N19E48   225  0010 Axx  01   01 Alpha
IA. H-alpha Plages without Spots.  Locations Valid at 04/2400Z Jan
Nmbr  Location  Lo
1636  N14W69   343
1637  N06W77   351
1639  S16W38   312
1643  S14E17   257
II. Regions Due to Return 05 Jan to 07 Jan
Nmbr Lat    Lo
None
"""

# Numpy returns NotImplemented when you try to compare lists of
# strings for equality. This is just insane. We provide here an
# alternative for all(np.equal(a, b))
def are_equal(list_a, list_b):
    if len(list_a) != len(list_b):
        return False
    return all([a == b for a, b in zip(list_a, list_b)])


sunspot_title_row = ['Nmbr', 'Location', 'Lo', 'Area', 'Z', 'LL', 'NN', 'Mag', 'Type']

def parse_sunspot(sunspot_file):
    """Parses a swpc sunspot file into a pandas-friendly form."""
    # Split into lines.
    lines = split_and_purge(sunspot_file, "\n")

    # Look for the first row that has 9 words. This is the title row.
    i = -1
    title_row = None
    for line in lines:
        i += 1
        if are_equal(sunspot_title_row, split_and_purge(line)):
            title_row = sunspot_title_row
            title_row = title_row[:7] + [" ".join(title_row[7:])]
            break
        else:
            continue

    if title_row is None:
        return ""

    # Get the rows.
    rows = []
    for line in lines[i + 1:]:
        items = split_and_purge(line)

        # We are done retrieving the rows we need.
        if len(items) != 8:
            break

        rows.append(items)

    # Create csv.
    strio = StringIO()
    writer = csv.writer(strio)
    writer.writerows([title_row] + rows)
    return strio.getvalue()

# Test the function above.
pd.read_csv(StringIO(parse_sunspot(sunspot_test)))
# Out:
#     Nmbr Location   Lo  Area    Z  LL  NN          Mag Type
# 0   1638   N13W34  308    80  Hsx   2   1             Alpha
# 1   1640   N28W48  322   320  Eki  13  24  Beta-Gamma-Delta
# 2   1641   N04W05  279    40  Cao   8   2              Beta
# 3   1642   S24E22  252   100  Hsx   2   1             Alpha
# 4   1644   N15E35  239    40  Hsx   2   1             Alpha
# 5   1645   S13W18  292    50  Dao   5   8              Beta
# 6   1646   N14E45  229    30  Hax   1   1             Alpha
# 7   1647   N16W55  329    30  Cao   5   4              Beta
# 8   1648   N05E53  221    20  Cro   3   2              Beta
# 9   1649   S14E74  200    60  Hsx   2   1             Alpha
# 10  1650   S26E77  197    50  Hsx   2   1             Alpha
# 11  1651   N19E48  225    10  Axx   1   1             Alpha

# %%
def get_sunspots(year) :
    """Returns a dataframe containing sunspot data for a given year."""
    # The prefix for the archive file for 2006 is different from the other years.
    file_pref = "" if year == 2006 or year == 2007 else "%s_" % year
    SUNSPOT_URL = "http://www.swpc.noaa.gov/ftpdir/warehouse/%s/%sSRS.tar.gz" % (year, file_pref)
    strio = StringIO(requests.get(SUNSPOT_URL).content)
    tarred = tarfile.open("r:gz", fileobj=strio)

    # Parse every file for the given year into a dataframe, then add the df
    # to a list.
    sunspot_by_day = []
    for tarinfo in tarred:
        if not tarinfo.isdir():
            extracted = tarred.extractfile(tarinfo).read()
            
            # The tar members are named like '2010_SRS/20100420SRS.txt'. We use
            # a regex to extract the day.
            day = re.match(r"^.*?SRS/(\d+)SRS.txt", tarinfo.name).group(1)
            
            df = pd.read_csv(StringIO(parse_sunspot(extracted)))
            df["Date"] = [day] * len(df)
            sunspot_by_day.append(df)

    # Form a single dataframe.
    sunspot = pd.concat(sunspot_by_day)
    sunspot.sort(["Date", "Nmbr"], ascending=[1, 1], inplace=True)
    sunspot.reset_index(drop=True, inplace=True)
    return sunspot

# Get spots for year 2013.
sunspot = get_sunspots(2013)
sunspot.head()
# Out:
#    Nmbr Location   Lo  Area    Z  LL  NN Mag Type      Date
# 0  1636   N14W13  340    30  Dso   4   6     Beta  20130101
# 1  1638   N13E17  308    90  Cao   2   3     Beta  20130101
# 2  1639   S16E17  310    10  Cso   2   2     Beta  20130101
# 3  1640   N28E06  320    80  Cao   8  11     Beta  20130101
# 4  1641   N05E52  274    40  Cso   5   3     Beta  20130101

# %%
grouped = sunspot.groupby('Mag Type')
print grouped.count()
# Out:
#                   Nmbr  Location    Lo  Area     Z    LL    NN  Date
# Mag Type
# Alpha              694       694   694   694   694   694   694   694
# Beta              1076      1076  1076  1076  1076  1076  1076  1076
# Beta-Delta          15        15    15    15    15    15    15    15
# Beta-Gamma         250       250   250   250   250   250   250   250
# Beta-Gamma-Delta    86        86    86    86    86    86    86    86

# %%
histData = sunspot[['Nmbr','Mag Type']]
histData = histData.groupby('Mag Type').count()
histData = histData[['Nmbr']]
histData.reset_index(inplace=True)
histData.head()
# Out:
#            Mag Type  Nmbr
# 0             Alpha   694
# 1              Beta  1076
# 2        Beta-Delta    15
# 3        Beta-Gamma   250
# 4  Beta-Gamma-Delta    86

# %%
plt.figure(figsize=(10,6))
plt.bar(histData.index,histData['Nmbr'],align='center')

plt.xlabel('Mag Type')
plt.ylabel('Number of events')
plt.title('2013 event count by Mag Type')
plt.xticks(histData.index,histData['Mag Type'])
plt.show()

# %%
count = 0
Xray_letter = ['NaN']*len(recent_flare_catalog['X-ray class'])

for event in recent_flare_catalog['X-ray class']:
    Xray_letter[count] = event[:1]
    count += 1

recent_flare_catalog['X-ray letter'] = Xray_letter
recent_flare_catalog.head()
# Out:
#    # event No.        GOES start               end              peak  \
# 0            0  2006/10/20 19:17  2006/10/20 19:48  2006/10/20 19:20
# 1           10  2006/10/21 15:13  2006/10/21 15:41  2006/10/21 15:25
# 2           20  2006/10/21 16:18  2006/10/21 16:30  2006/10/21 16:21
# 3           30  2006/10/21 18:03  2006/10/21 18:19  2006/10/21 18:10
# 4           40  2006/10/21 18:24  2006/10/21 19:28  2006/10/21 18:58
#
#   AR location X-ray class  event loc. (EW)  event loc. (NS) SOT XRT  EIS  \
# 0      S05W19        A4.3              320             -177   0   0    0
# 1      S03W27        A6.4              452             -132   0   0    0
# 2      S03W28        A7.1              460             -132   0   0    0
# 3      S02W29        A7.1              478             -122   0   0    0
# 4      S03W32        A7.8              523             -143   0   0    0
#
#   latitude longitude X-ray letter
# 0       05        19            A
# 1       03        27            A
# 2       03        28            A
# 3       02        29            A
# 4       03        32            A

# %%
flare_class_group = recent_flare_catalog[['X-ray class', 'X-ray letter']]
flare_class_group = flare_class_group.groupby('X-ray letter').count()
flare_class_group = flare_class_group[['X-ray class']]
flare_class_group.reset_index(inplace=True)
flare_class_group.head()
# Out:
#   X-ray letter  X-ray class
# 0            A          260
# 1            B         4812
# 2            C         5788
# 3            M          548
# 4            X           45

# %% [markdown]
# Flare class is a log scale that gives a label to the magnitude of the flare.  The flare categories are A, B, C, M, with A being the smallest and X being the largest. Ordinarily, you would expect that there would be more A and B flares than C flares.  However, this data is from late 2013 and 2014.  This timeframe is near solar maximum, so there is constantly a lot of activity.  The A and B flares are getting lost in the noise of the solar activity.  Notice in the original flare_catalog dataframe from above that in 2006 there were a lot of A and B flares, and fewer large flares.  This is because the general background noise of solar activity is very low during solar minimum, so small flares can more easily be detected.
#
# ![Flare Levels](http://www.swpc.noaa.gov/rt_plots/xray_5m.html)

# %%
plt.figure(figsize=(10,6))
plt.bar(flare_class_group.index,flare_class_group['X-ray class'],align='center')

plt.xlabel('Flare class')
plt.ylabel('Number of Events')
plt.title('Event Count since 8/01/2013 by Flare Class')
plt.xticks(flare_class_group.index,flare_class_group['X-ray letter'])
plt.show()

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('-wEh-mFcEHY')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/-wEh-mFcEHY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
get_sunspots(2009).head()
# Out:
#    Nmbr Location  Lo  Area    Z  LL  NN Mag Type      Date
# 0  1010   N18E33  19    20  Bxo   3   4     Beta  20090110
# 1  1010   N20E19  20    30  Dso   5   7     Beta  20090111
# 2  1010   N18E05  21    50  Bxo   6  10     Beta  20090112
# 3  1010   N19W08  21    10  Axx   1   2    Alpha  20090113
# 4  1010   N18W20  19    10  Axx   1   1    Alpha  20090114

# %% [markdown]
# The Heliophysics Event Knowledgebase (HEK) is a repository of feature and event information concerning the Sun. Entries are generated both by automated algorithms and human observers. The SunPy library accesses this information through the ‘hek’ module, which was developed through support from the European Space Agency Summer of Code in Space (ESA-SOCIS) 2011.
#
# Fetching data using the HEK module is slow. We can speed up data retrieval significantly by leveraging the multiprocessing capabilities of IPython.
#
# We need to fire up a cluster before we do any multiprocessing with the IPython notebook. We use 25 engines for the cluster.

# %%
# %%bash
# ipcluster stop
# ipcluster start -n 25 --daemonize
# Out:
# 2014-12-06 03:55:58.580 [IPClusterStop] Using existing profile dir: u'/home/ogaro/.ipython/profile_default'
# 2014-12-06 03:55:58.581 [IPClusterStop] CRITICAL | Could not read pid file, cluster is probably not running.
# 2014-12-06 03:55:58.888 [IPClusterStart] Using existing profile dir: u'/home/ogaro/.ipython/profile_default'

# %%
# Create a parallelization client after initializing a cluster.
from IPython.parallel import Client

cli = Client()
dview = cli[:]

# %%
# The @dview.parallel decorator turns a function into one that is
# automatically parallelized by IPython. Its arguments are split and sent to
# multiple engines, and its return values can be combined into a single value.

@dview.parallel(block=True)
def query_hek(hinode_event):
    """Queries HEK for a hinode flare matching given parameters."""
    import numpy as np
    import pandas as pd
    from datetime import datetime
    from datetime import timedelta
    from sunpy.net import hek
    
    # Error margin for start time.
    delta_T = timedelta(minutes=5)

    # HEK client.
    client = hek.HEKClient()

    start_time = pd.to_datetime(hinode_event["GOES start"]) - delta_T
    end_time = start_time + 2 * delta_T
       
    try:
        # Query parameters:
        #   - Time range
        #   - FLARE event type
        #   - Only choose Flare Detective triggers
        hek_events = client.query(hek.attrs.Time(start_time.isoformat(),
                                                 end_time.isoformat()),
                                  hek.attrs.EventType('FL'),
                                  #hek.attrs.OBS.ChannelID == "131",
                                  #hek.attrs.FRM.Name == 'Flare Detective - Trigger Module'
                                  )
    except Exception as _ :
        return None

    for hek_event in hek_events:
        # Calculate the Euclidean distance between the Hinode event and the HEK event.
        hek_event["distance"] = np.sqrt(
            (hinode_event["event loc. (EW)"] - hek_event["event_coord1"])**2 +
            (hinode_event["event loc. (NS)"] - hek_event["event_coord2"])**2)

        # Calculate the time difference between the Hinode event and the HEK event.
        delta = (pd.to_datetime(hinode_event["peak"]) -
                 pd.to_datetime(hek_event["event_peaktime"]))
        hek_event["time_diff"] = delta.total_seconds()

    return(hek_events)

# Create a list of flares to query.
flares = []
i = 0
for _, fl in recent_flare_catalog.iterrows():
    flares.append(fl)
    i += 1
    if i >= 50: break


query_hek.map(flares)
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{u'SOL_standard': u'SOL2006-10-22T06:54:00L311C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 620.14353177308885,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-22T07:18:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-22T07:01:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-22T06:54:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B6.5',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-22T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((-139.16869 -89.9,40.63131 -89.9,40.63131 89.9,-139.16869 89.9,-139.16869 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-49.26869 0)',
#    u'hgc_x': -49.26869,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -958.986,-8.4e-05 -958.986,0 959.814,-0 959.814,8.4e-05 -958.986))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -89.5272)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -89.5272,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.995286 180.000005,0.995286 179.999995,0.996145 0,0.996145 0,0.995286 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0929160374339319 180)',
#    u'hrc_r': 0.0929160374339319,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:16',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001342_679',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-10-22T08:41:00L310C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 690.39843568768322,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-22T08:46:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-22T08:44:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-22T08:41:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.6',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-22T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((-140.1487 -89.9,39.6513 -89.9,39.6513 89.9,-140.1487 89.9,-140.1487 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-50.2487 0)',
#    u'hgc_x': -50.2487,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -959.016,-8.4e-05 -959.016,0 959.844,-0 959.844,8.4e-05 -959.016))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -89.4216)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -89.4216,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.995297 180.000005,0.995297 179.999995,0.996156 0,0.996156 0,0.995297 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0928045196300049 180)',
#    u'hrc_r': 0.0928045196300049,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:18',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001343_777',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-10-22T11:07:00L309C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 629.64116765027359,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-22T11:12:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-22T11:10:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-22T11:07:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.0',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-22T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((-141.4859 -89.9,38.3141 -89.9,38.3141 89.9,-141.4859 89.9,-141.4859 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-51.5859 0)',
#    u'hgc_x': -51.5859,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -959.058,-8.4e-05 -959.058,0 959.88,-0 959.88,8.4e-05 -959.058))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -89.2776)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -89.2776,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.995312 180.000005,0.995312 179.999995,0.996165 0,0.996165 0,0.995312 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0926524554998105 180)',
#    u'hrc_r': 0.0926524554998105,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:19',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001344_920',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-10-22T13:19:00L308C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 727.36785741466474,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-22T13:32:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-22T13:26:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-22T13:19:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B2.9',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-22T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((-142.69488 -89.9,37.10512 -89.9,37.10512 89.9,-142.69488 89.9,-142.69488 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-52.79488 0)',
#    u'hgc_x': -52.79488,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -959.094,-8.4e-05 -959.094,0 959.916,-0 959.916,8.4e-05 -959.094))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -89.1468)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -89.1468,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.995324 180.000005,0.995324 179.999995,0.996177 0,0.996177 0,0.995324 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0925143481776852 180)',
#    u'hrc_r': 0.0925143481776852,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:21',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001346_851',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-10-22T17:43:00L305C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 777.80460271201787,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-22T17:56:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-22T17:49:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-22T17:43:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B2.8',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-22T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((-145.11282 -89.9,34.68718 -89.9,34.68718 89.9,-145.11282 89.9,-145.11282 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-55.21282 0)',
#    u'hgc_x': -55.21282,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -959.166,-8.4e-05 -959.166,0 959.988,-0 959.988,8.4e-05 -959.166))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -88.8852)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -88.8852,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.995348 180.000005,0.995348 179.999995,0.996201 0,0.996201 0,0.995348 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.092238155652806 180)',
#    u'hrc_r': 0.092238155652806,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:22',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001347_711',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-10-22T18:09:00L305C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 745.83175046386975,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-22T18:15:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-22T18:12:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-22T18:09:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.0',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-22T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((-145.35095 -89.9,34.44905 -89.9,34.44905 89.9,-145.35095 89.9,-145.35095 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-55.45095 0)',
#    u'hgc_x': -55.45095,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -959.178,-8.4e-05 -959.178,0 960,-0 960,8.4e-05 -959.178))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -88.8588)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -88.8588,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.995355 180.000005,0.995355 179.999995,0.996208 0,0.996208 0,0.995355 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0922102956935426 180)',
#    u'hrc_r': 0.0922102956935426,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:23',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001348_457',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{u'SOL_standard': u'SOL2006-10-28T05:26:00L233C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 938.05810054601625,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-28T05:34:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-28T05:32:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-28T05:26:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.4',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-28T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((142.50872 -89.9,-37.69128 -89.9,-37.69128 89.9,142.50872 89.9,142.50872 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-127.59128 0)',
#    u'hgc_x': -127.59128,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -961.404,-8.4e-05 -961.404,0 962.154,-0 962.154,8.4e-05 -961.404))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -80.61)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -80.61,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.99615 180.000005,0.99615 179.999995,0.996928 0,0.996928 0,0.99615 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0835233590776137 180)',
#    u'hrc_r': 0.0835233590776137,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:28',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001352_264',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-10-28T06:54:00L232C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 922.61042699505629,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-28T07:00:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-28T06:58:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-28T06:54:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.2',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-28T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((141.70283 -89.9,-38.49717 -89.9,-38.49717 89.9,141.70283 89.9,141.70283 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-128.39717 0)',
#    u'hgc_x': -128.39717,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -961.428,-8.4e-05 -961.428,0 962.178,-0 962.178,8.4e-05 -961.428))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -80.5134)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -80.5134,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996159 180.000005,0.996159 179.999995,0.996936 0,0.996936 0,0.996159 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.083421863218623 180)',
#    u'hrc_r': 0.083421863218623,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-05-29T00:06:00',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001353_024',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5.000000058430487e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'3',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0},
#   {u'SOL_standard': u'SOL2006-10-28T06:54:00L232C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 922.61042699505629,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-28T07:00:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-28T06:58:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-28T06:54:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.2',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-28T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((141.70283 -89.9,-38.49717 -89.9,-38.49717 89.9,141.70283 89.9,141.70283 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-128.39717 0)',
#    u'hgc_x': -128.39717,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -961.428,-8.4e-05 -961.428,0 962.178,-0 962.178,8.4e-05 -961.428))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -80.5134)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -80.5134,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996159 180.000005,0.996159 179.999995,0.996936 0,0.996936 0,0.996159 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.083421863218623 180)',
#    u'hrc_r': 0.083421863218623,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-03-10T18:32:23',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SWPC_20140112_182748_20061028065400',
#    u'kb_archivist': u'rtimmons',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5.000000058430487e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'1',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [],
#  [{u'SOL_standard': u'SOL2006-10-28T21:09:00L224C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 420.11903075200007,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-28T21:15:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-28T21:13:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-28T21:09:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B2.5',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-28T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((133.87293 -89.9,-46.32707 -89.9,-46.32707 89.9,133.87293 89.9,133.87293 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-136.22707 0)',
#    u'hgc_x': -136.22707,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -961.668,-8.4e-05 -961.668,0 962.406,-0 962.406,8.4e-05 -961.668))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -79.5684)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -79.5684,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996245 180.000005,0.996245 179.999995,0.997009 0,0.997009 0,0.996245 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0824292599610802 180)',
#    u'hrc_r': 0.0824292599610802,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:30',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001354_539',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [],
#  [],
#  [{u'SOL_standard': u'SOL2006-10-30T09:09:00L204C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 997.34447409107349,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-10-30T09:35:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-10-30T09:20:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-10-30T09:09:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.7',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-10-30T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((114.09252 -89.9,-66.10748 -89.9,-66.10748 89.9,114.09252 89.9,114.09252 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(-156.00748 0)',
#    u'hgc_x': -156.00748,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -962.274,-8.4e-05 -962.274,0 962.988,-0 962.988,8.4e-05 -962.274))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -77.1414)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -77.1414,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996464 180.000005,0.996464 179.999995,0.997203 0,0.997203 0,0.996464 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0798822461378142 180)',
#    u'hrc_r': 0.0798822461378142,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:32',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001356_046',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
# ...
#    u'event_starttime': u'2006-11-02T04:05:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.6',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-11-02T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((77.31715 -89.9,-102.88285 -89.9,-102.88285 89.9,77.31715 89.9,77.31715 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(167.21715 0)',
#    u'hgc_x': 167.21715,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -963.378,-8.4e-05 -963.378,0 964.05,-0 964.05,8.4e-05 -963.378))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -72.4788)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -72.4788,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996861 180.000005,0.996861 179.999995,0.997556 0,0.997556 0,0.996861 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0749978642638697 180)',
#    u'hrc_r': 0.0749978642638697,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:53',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001409_092',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-11-02T02:01:00L167C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 713.00631133251545,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-11-02T04:12:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-11-02T04:08:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-11-02T02:01:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B1.6',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-11-02T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((77.31715 -89.9,-102.88285 -89.9,-102.88285 89.9,77.31715 89.9,77.31715 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(167.21715 0)',
#    u'hgc_x': 167.21715,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -963.378,-8.4e-05 -963.378,0 964.05,-0 964.05,8.4e-05 -963.378))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -72.4788)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -72.4788,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996861 180.000005,0.996861 179.999995,0.997556 0,0.997556 0,0.996861 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0749978642638697 180)',
#    u'hrc_r': 0.0749978642638697,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:53',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001409_092',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 900.0},
#   {u'SOL_standard': u'SOL2006-11-02T04:13:00L167C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 10922,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 713.00631133251545,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-11-02T04:33:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-11-02T04:23:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-11-02T04:13:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'C1.0',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-11-02T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((77.24389 -89.9,-102.95611 -89.9,-102.95611 89.9,77.24389 89.9,77.24389 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(167.14389 0)',
#    u'hgc_x': 167.14389,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -963.378,-8.4e-05 -963.378,0 964.056,-0 964.056,8.4e-05 -963.378))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -72.4692)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -72.4692,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.99686 180.000005,0.99686 179.999995,0.997561 0,0.997561 0,0.99686 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0749878211997847 180)',
#    u'hrc_r': 0.0749878211997847,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:54',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001409_989',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}],
#  [{u'SOL_standard': u'SOL2006-11-02T05:57:00L166C090',
#    u'active': u'true',
#    u'ar_compactnesscls': u'',
#    u'ar_mcintoshcls': u'',
#    u'ar_mtwilsoncls': u'',
#    u'ar_noaaclass': u'',
#    u'ar_noaanum': 0,
#    u'ar_numspots': None,
#    u'ar_penumbracls': u'',
#    u'ar_polarity': None,
#    u'ar_zurichcls': u'',
#    u'area_atdiskcenter': None,
#    u'area_atdiskcenteruncert': None,
#    u'area_raw': None,
#    u'area_uncert': None,
#    u'area_unit': u'',
#    u'bound_ccnsteps': None,
#    u'bound_ccstartc1': None,
#    u'bound_ccstartc2': None,
#    u'bound_chaincode': u'',
#    u'boundbox_c1ll': -90,
#    u'boundbox_c1ur': 90,
#    u'boundbox_c2ll': -90,
#    u'boundbox_c2ur': 90,
#    u'chaincodetype': u'',
#    u'comment_count': u'0',
#    u'concept': u'Flare ',
#    'distance': 547.16816427858816,
#    u'event_avg_rating': None,
#    u'event_c1error': 90,
#    u'event_c2error': 90,
#    u'event_clippedspatial': u'',
#    u'event_clippedtemporal': u'',
#    u'event_coord1': 0,
#    u'event_coord2': 0,
#    u'event_coord3': None,
#    u'event_coordsys': u'UTC-HGS-TOPO',
#    u'event_coordunit': u'degrees',
#    u'event_description': u'',
#    u'event_endtime': u'2006-11-02T06:03:00',
#    u'event_expires': u'',
#    u'event_importance': None,
#    u'event_importance_num_ratings': u'',
#    u'event_mapurl': u'',
#    u'event_maskurl': u'',
#    u'event_npixels': None,
#    u'event_peaktime': u'2006-11-02T06:00:00',
#    u'event_pixelunit': u'',
#    u'event_probability': None,
#    u'event_score': u'',
#    u'event_starttime': u'2006-11-02T05:57:00',
#    u'event_testflag': u'false',
#    u'event_title': u'',
#    u'event_type': u'FL',
#    u'eventtype': u'9',
#    u'fl_efoldtime': None,
#    u'fl_efoldtimeunit': u'',
#    u'fl_fluence': None,
#    u'fl_fluenceunit': u'',
#    u'fl_goescls': u'B2.3',
#    u'fl_peakem': None,
#    u'fl_peakemunit': u'',
#    u'fl_peakflux': None,
#    u'fl_peakfluxunit': u'',
#    u'fl_peaktemp': None,
#    u'fl_peaktempunit': u'',
#    u'frm_contact': u'SWPC.Webmaster@noaa.gov',
#    u'frm_daterun': u'2006-11-02T00:00:00',
#    u'frm_humanflag': u'false',
#    u'frm_identifier': u'SWPC',
#    u'frm_institute': u'U.S. Dept. of Commerce, NOAA, Space Weather Prediction Center',
#    u'frm_name': u'SWPC',
#    u'frm_paramset': u'-',
#    u'frm_specificid': u'',
#    u'frm_url': u'http://www.swpc.noaa.gov/',
#    u'frm_versionnumber': None,
#    u'gs_galleryid': u'',
#    u'gs_imageurl': u'',
#    u'gs_movieurl': u'',
#    u'gs_thumburl': u'',
#    u'hcr_checked': u'true',
#    u'hgc_bbox': u'POLYGON((76.29157 -89.9,-103.90843 -89.9,-103.90843 89.9,76.29157 89.9,76.29157 -89.9))',
#    u'hgc_boundcc': u'',
#    u'hgc_coord': u'POINT(166.19157 0)',
#    u'hgc_x': 166.19157,
#    u'hgc_y': 0,
#    u'hgs_bbox': u'POLYGON((-89.9 -89.9,89.9 -89.9,89.9 89.9,-89.9 89.9,-89.9 -89.9))',
#    u'hgs_boundcc': u'',
#    u'hgs_coord': u'POINT(0 0)',
#    u'hgs_x': 0,
#    u'hgs_y': 0,
#    u'hpc_bbox': u'POLYGON((8.4e-05 -963.408,-8.4e-05 -963.408,0 964.08,-0 964.08,8.4e-05 -963.408))',
#    u'hpc_boundcc': u'',
#    u'hpc_coord': u'POINT(0 -72.3456)',
#    u'hpc_geom': u'',
#    u'hpc_x': 0,
#    u'hpc_y': -72.3456,
#    u'hrc_a': 180,
#    u'hrc_bbox': u'POLYGON((0.996872 180.000005,0.996872 179.999995,0.997567 0,0.997567 0,0.996872 180.000005))',
#    u'hrc_boundcc': u'',
#    u'hrc_coord': u'POINT(0.0748584979692712 180)',
#    u'hrc_r': 0.0748584979692712,
#    u'intenskurt': None,
#    u'intensmax': None,
#    u'intensmean': None,
#    u'intensmedian': None,
#    u'intensmin': None,
#    u'intensskew': None,
#    u'intenstotal': None,
#    u'intensunit': u'',
#    u'intensvar': None,
#    u'kb_archivdate': u'2014-01-12T18:18:55',
#    u'kb_archivid': u'ivo://helio-informatics.org/FL_SECstandard_20090903_001410_513',
#    u'kb_archivist': u'cheung_mark',
#    u'noposition': u'true',
#    u'obs_channelid': u'XRA',
#    u'obs_dataprepurl': u'',
#    u'obs_firstprocessingdate': u'',
#    u'obs_includesnrt': u'',
#    u'obs_instrument': u'GOES',
#    u'obs_lastprocessingdate': u'',
#    u'obs_levelnum': None,
#    u'obs_meanwavel': 5e-08,
#    u'obs_observatory': u'GOES',
#    u'obs_title': u'',
#    u'obs_wavelunit': u'cm',
#    u'rasterscan': u'',
#    u'rasterscantype': u'',
#    u'refs': [{u'ref_name': u'FRM_URL',
#      u'ref_type': u'unknown',
#      u'ref_url': u'http://www.swpc.noaa.gov/'}],
#    u'refs_orig': u'',
#    u'revision': u'2',
#    u'skel_chaincode': u'',
#    u'skel_curvature': None,
#    u'skel_nsteps': None,
#    u'skel_startc1': None,
#    u'skel_startc2': None,
#    'time_diff': 0.0}]]
